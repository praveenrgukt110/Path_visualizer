# %%
import folium
from branca.element import Figure

fig=Figure(width=750,height=750)
map1=folium.Map(location=[16.7850, 80.8488],zoom_start=12,min_zoom=8,max_zoom=14)
fig.add_child(map1)
map1

path1=[[16.7850, 80.8488],[16.677562389449363, 80.95112597617178],[16.688744011742127, 80.98889147666661],[16.68940173386151, 81.02322374984372],[16.74595735942457, 81.08502184156252],[16.806440134687936, 81.25119004373978],[16.985802483220645, 81.47640977543763],[17.049490789053266, 81.54850756101824],[17.02126050352569, 81.66867051713815],[17.05671180517022, 81.79501328242995],[17.37905211293079, 82.53975108322598],[17.515303623763558, 82.81440926864292],[17.685384168117885, 83.02856532891387],[17.68831376226653, 83.02738769126638],[17.68557116520231, 83.21809957311659]]
path2=[[16.7850, 80.8488],[16.678823575908552, 80.78112273690283],[16.651195771374443, 80.73099761806422],[16.595270170195665, 80.71451812693921],[16.574211607196027, 80.68018585376211],[16.527479697818134, 80.63898712594955],[16.511022105649054, 80.62044769843392],[16.62012582476842, 80.9700610093558],[16.738118237122098, 81.08043837838821],[16.756500098950177, 81.21321115563009],[17.04883789020161, 81.54434326272732],[17.019777516948064, 81.67391673946263],[17.377639446524856, 82.53649364166701],[17.65254055787111, 82.89487852715375],[17.697079775310236, 83.22209950955468]]

f1=folium.FeatureGroup("Vehicle 1")
f2=folium.FeatureGroup("Vehicle 2")


line_1=folium.vector_layers.PolyLine(path1,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(path2,popup='<b>Path of Vehicle_2</b>',tooltip='Vehicle_2',color='red',weight=10).add_to(f2)
f1.add_to(map1)
f2.add_to(map1)

17.47553603748228, 82.781758844228

folium.Marker(location=[17.68557116520231, 83.21809957311659],popup='',tooltip='My Home',icon=folium.Icon(color='purple',prefix='fa',icon="fa-home")).add_to(map1)
folium.Marker(location=[16.73693545105855, 81.14276064572249],popup='',tooltip='Asram Medical College Eluru',icon=folium.Icon(color='blue',prefix='fa',icon="fa-graduation-cap")).add_to(map1)
folium.Marker(location=[16.68505801344202, 80.98410778992701],popup='',tooltip='Ravi Raju Cafe',icon=folium.Icon(color='orange',prefix='fa',icon="fa-coffee")).add_to(map1)
folium.Marker(location=[16.78581915287105, 81.22248107120265],popup='',tooltip='Simhacalam Cool Drinks',icon=folium.Icon(color='orange',prefix='fa',icon="fa-coffee")).add_to(map1)
folium.Marker(location=[17.230380963297595, 82.20633681677383],popup='',tooltip='Degree College',icon=folium.Icon(color='blue',prefix='fa',icon="fa-graduation-cap")).add_to(map1)
folium.Marker(location=[17.47553603748228, 82.781758844228],popup='',tooltip='S Cinemas',icon=folium.Icon(color='green',prefix='fa',icon="fa-film")).add_to(map1)

map1
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import folium
from branca.element import Figure
# define the world map
world_map = folium.Map()
# display world map
world_map

fig=Figure(width=550,height=350)
map1=folium.Map(location=[16.7850, 80.8488],zoom_start=12,min_zoom=8,max_zoom=14)
fig.add_child(map1)
map1

path1=[[16.7850, 80.8488],[16.677562389449363, 80.95112597617178],[16.688744011742127, 80.98889147666661],[16.68940173386151, 81.02322374984372],[16.74595735942457, 81.08502184156252],[16.806440134687936, 81.25119004373978],[16.985802483220645, 81.47640977543763],[17.049490789053266, 81.54850756101824],[17.02126050352569, 81.66867051713815],[17.05671180517022, 81.79501328242995],[17.37905211293079, 82.53975108322598],[17.515303623763558, 82.81440926864292],[17.685384168117885, 83.02856532891387],[17.68831376226653, 83.02738769126638],[17.68557116520231, 83.21809957311659]]
path2=[[16.7850, 80.8488],[16.678823575908552, 80.78112273690283],[16.651195771374443, 80.73099761806422],[16.595270170195665, 80.71451812693921],[16.574211607196027, 80.68018585376211],[16.527479697818134, 80.63898712594955],[16.511022105649054, 80.62044769843392],[16.62012582476842, 80.9700610093558],[16.738118237122098, 81.08043837838821],[16.756500098950177, 81.21321115563009],[17.04883789020161, 81.54434326272732],[17.019777516948064, 81.67391673946263],[17.377639446524856, 82.53649364166701],[17.65254055787111, 82.89487852715375],[17.697079775310236, 83.22209950955468]]

f1=folium.FeatureGroup("Vehicle 1")
f2=folium.FeatureGroup("Vehicle 2")


line_1=folium.vector_layers.PolyLine(path1,popup='<b>Path of Vehicle_1</b>',tooltip='Vehicle_1',color='blue',weight=10).add_to(f1)
line_2=folium.vector_layers.PolyLine(path2,popup='<b>Path of Vehicle_2</b>',tooltip='Vehicle_2',color='red',weight=10).add_to(f2)
f1.add_to(map1)
f2.add_to(map1)

folium.Marker(location=[17.68557116520231, 83.21809957311659],popup='My Home',tooltip='Click here to see more details',icon=folium.Icon(color='purple',prefix='fa-solid',icon="fa-plane")).add_to(map1)

map1
